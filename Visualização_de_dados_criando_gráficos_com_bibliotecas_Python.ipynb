# %% [markdown]
# <a href="https://colab.research.google.com/github/alra-code/alura-aprendendo-a-fazer-ETL/blob/main/Visualiza%C3%A7%C3%A3o_de_dados_criando_gr%C3%A1ficos_com_bibliotecas_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importação da biblioteca
import pandas as pd

#Armazenando o dataset
df = pd.read_csv('/content/imigrantes_canada.csv')

#visualizando o dataframe
df
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %%
#conhecendo o dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   País        195 non-null    object
#  1   Continente  195 non-null    object
#  2   Região      195 non-null    object
#  3   1980        195 non-null    int64
#  4   1981        195 non-null    int64
#  5   1982        195 non-null    int64
#  6   1983        195 non-null    int64
#  7   1984        195 non-null    int64
#  8   1985        195 non-null    int64
#  9   1986        195 non-null    int64
#  10  1987        195 non-null    int64
#  11  1988        195 non-null    int64
#  12  1989        195 non-null    int64
#  13  1990        195 non-null    int64
#  14  1991        195 non-null    int64
#  15  1992        195 non-null    int64
#  16  1993        195 non-null    int64
#  17  1994        195 non-null    int64
#  18  1995        195 non-null    int64
# ...

# %%
#substiundo o index pela coluna país
df.set_index('País', inplace=True)

# %%
df
# Out:
#                 Continente            Região  1980  1981  1982  1983  1984  \
# País
# Afeganistão           Ásia       Sul da Ásia    16    39    39    47    71
# Albânia             Europa     Sul da Europa     1     0     0     0     0
# Argélia             África   Norte da África    80    67    71    69    63
# Samoa Americana    Oceânia         Polinésia     0     1     0     0     0
# Andorra             Europa     Sul da Europa     0     0     0     0     0
# ...                    ...               ...   ...   ...   ...   ...   ...
# Vietnã                Ásia  Sudeste Asiático  1191  1829  2162  3404  7583
# Saara Ocidental     África   Norte da África     0     0     0     0     0
# Iémen                 Ásia    Ásia Ocidental     1     2     1     6     0
# Zâmbia              África   África Oriental    11    17    11     7    16
# Zimbábue            África   África Oriental    72   114   102    44    32
#
# ...

# %%
#criando intervalo de anos
anos = list(map(str, range(1980, 2014)))

# %%
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
#separando so dados somente do Brasil
brasil = df.loc['Brasil', anos]

# %%
brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brasil, dtype: object

# %%
argentina = df.loc['Argentina', anos]
argentina
# Out:
# 1980     368
# 1981     426
# 1982     626
# 1983     241
# 1984     237
# 1985     196
# 1986     213
# 1987     519
# 1988     374
# 1989     538
# 1990     678
# 1991     763
# 1992    1023
# 1993    1022
# 1994     366
# 1995     380
# 1996     396
# 1997     391
# 1998     349
# 1999     318
# 2000     427
# 2001     635
# 2002     865
# 2003    1745
# 2004    1591
# 2005    1153
# 2006     847
# 2007     620
# 2008     540
# 2009     467
# 2010     459
# 2011     278
# 2012     263
# 2013     282
# Name: Argentina, dtype: object

# %%
#transformando a variavel brasil em dataframe
brasil_dict = {'ano':brasil.index.tolist(),'imigrantes':brasil.values.tolist()}
dados_brasil = pd.DataFrame(brasil_dict)

# %%
dados_brasil
# Out:
#      ano  imigrantes
# 0   1980         211
# 1   1981         220
# 2   1982         192
# 3   1983         139
# 4   1984         145
# 5   1985         130
# 6   1986         205
# 7   1987         244
# 8   1988         394
# 9   1989         650
# 10  1990         650
# 11  1991         877
# 12  1992        1066
# 13  1993         866
# 14  1994         566
# 15  1995         572
# 16  1996         586
# 17  1997         591
# 18  1998         531
# 19  1999         626
# 20  2000         845
# 21  2001         847
# 22  2002         745
# 23  2003         839
# 24  2004         917
# 25  2005         969
# 26  2006        1181
# 27  2007        1746
# 28  2008        2138
# 29  2009        2509
# 30  2010        2598
# 31  2011        1508
# 32  2012        1642
# 33  2013        1714

# %%
argentina_dict = {'ano':argentina.index.tolist(),'imigrantes':argentina.values.tolist()}
dados_argentina = pd.DataFrame(argentina_dict)

# %%
#criando gráfico para análise dos dados
#importação da biblioteca para criar gráficos
import matplotlib.pyplot as plt

# %%
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'])

# %%
#melhorando o grafico eixo X
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
plt.xticks(['1980','1985','1990','1995','2000','2005','2010','2014'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f49b6596c50>,
# ...
#  [Text(0.0, 0, '1980'),
#   Text(5.0, 0, '1985'),
#   Text(10.0, 0, '1990'),
#   Text(15.0, 0, '1995'),
#   Text(20.0, 0, '2000'),
#   Text(25.0, 0, '2005'),
#   Text(30.0, 0, '2010'),
#   Text(34.0, 0, '2014')])

# %%
#melhorando o grafico eixo Y
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
plt.xticks(['1980','1985','1990','1995','2000','2005','2010','2014'])
plt.yticks([500, 1000, 1500, 2000, 2500, 3000 ])
# Out:
# ([<matplotlib.axis.YTick at 0x7f49b763cdd0>,
# ...
#  [Text(0, 500, '500'),
#   Text(0, 1000, '1000'),
#   Text(0, 1500, '1500'),
#   Text(0, 2000, '2000'),
#   Text(0, 2500, '2500'),
#   Text(0, 3000, '3000')])

# %%
#Exibindo somente o gráfico
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
plt.xticks(['1980','1985','1990','1995','2000','2005','2010','2014'])
plt.show()

# %%
#Alterando o tamanho do gráfico
plt.figure(figsize=(10,5))
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
plt.xticks(['1980','1985','1990','1995','2000','2005','2010','2014'])
plt.show()

# %%
#Incluindo Titulo no gráfico
plt.figure(figsize=(10,5))
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
plt.title('Imigração do Brasil para o Canada')
plt.xticks(['1980','1985','1990','1995','2000','2005','2010','2014'])
plt.show()

# %%
#Incluindo os rotulos no gráfico
plt.figure(figsize=(10,5))
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
plt.title('Imigração do Brasil para o Canada')
plt.xlabel('Ano')
plt.ylabel('Imigrantes')
plt.xticks(['1980','1985','1990','1995','2000','2005','2010','2014'])
plt.show()

# %%
#Criando uma figura
fig, ax = plt.subplots(figsize = (8,4))
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
ax.set_title('Imigração do Brasil para o Canadá\n(1980-2014)')
ax.set_xlabel('Ano')
ax.set_ylabel('Número de Imigrantes')
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
plt.show()

# %%
#Criando subplots
#cirando o primeiro gráfico
fig, axs = plt.subplots(1,2, figsize = (15,5))
axs[0].plot(dados_brasil['ano'], dados_brasil['imigrantes'])
axs[0].set_title('Imigração do Brasil para o Canadá\n(1980-2014)')
axs[0].set_xlabel('Ano')
axs[0].set_ylabel('Número de Imigrantes')
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5))
axs[0].grid()

#criando o segundo gráfico
axs[1].boxplot(dados_brasil['imigrantes'])
axs[1].set_title('Boxplot dos Imigrantes\n(1980-2014)')
axs[1].set_xlabel('Brasil')
axs[1].set_ylabel('Número de Imigrantes')
axs[1].grid()
plt.show()

# %%
#Conferindo os valores
dados_brasil.describe()
# Out:
#         imigrantes
# count    34.000000
# mean    872.323529
# std     663.401232
# min     130.000000
# 25%     428.250000
# 50%     697.500000
# 75%    1041.750000
# max    2598.000000

# %% [markdown]
# ##**Desafio: Comparando tendências de imigração**

# %%
#extraindo os dados para o Brasil e Argentina
df_comparacao = df.loc[['Brasil','Argentina'], anos]
#Transpondo a quantidade de imigrantes para cada país e seu respectivo ano
df_comparacao = df_comparacao.T
#visualizando o dataframe
df_comparacao.head()
# Out:
# País  Brasil  Argentina
# 1980     211        368
# 1981     220        426
# 1982     192        626
# 1983     139        241
# 1984     145        237

# %%
#plotando o gráfico de linhas, com rotulos e xticks de marcação
plt.plot(df_comparacao['Brasil'],label = 'Brasil')
plt.plot(df_comparacao['Argentina'],label ='Argentina')
plt.title('Imigração do Brasil e Argentina para o Canadá')
plt.xlabel('Ano')
plt.ylabel('Número de imigrantes')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.legend()
plt.show()

# %% [markdown]
# *Até o ano 2000 a imigração em ambos os países eram bem semelhantes, a partir de 2000, houve um aumento da imigração na Argentina, reduzindo a partir de 2005.
# A partir de 2005 até 2010 houve o aumento de imigração no Brasil para o Canada.*

# %% [markdown]
# ##**Criando subplots em duas direções**

# %%
#Criando 4 subplots para comparar 4 paises e ajustando eles
fig, axs = plt.subplots(2,2, figsize = (10,6))
fig.subplots_adjust(hspace = 0.5, wspace=0.3)
axs[0,0].plot(df.loc['Brasil', anos])
axs[0,0].set_title('Brasil')

axs[0,1].plot(df.loc['Colômbia', anos])
axs[0,1].set_title('Colômbia')

axs[1,0].plot(df.loc['Argentina', anos])
axs[1,0].set_title('Argentina')

axs[1,1].plot(df.loc['Peru', anos])
axs[1,1].set_title('Peru')

plt.show()

# %%
# criando 4 figuras
fig, axs = plt.subplots(2,2, figsize = (10,6))
fig.subplots_adjust(hspace = 0.5, wspace=0.3)
axs[0,0].plot(df.loc['Brasil', anos])
axs[0,0].set_title('Brasil')

axs[0,1].plot(df.loc['Colômbia', anos])
axs[0,1].set_title('Colômbia')

axs[1,0].plot(df.loc['Argentina', anos])
axs[1,0].set_title('Argentina')

axs[1,1].plot(df.loc['Peru', anos])
axs[1,1].set_title('Peru')
#ajustando o eixo de X (anos)
for ax in axs.flat:
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))
plt.show()

# %%
#criando 4 figuras
fig, axs = plt.subplots(2,2, figsize = (10,6))
fig.subplots_adjust(hspace = 0.5, wspace=0.3)
axs[0,0].plot(df.loc['Brasil', anos])
axs[0,0].set_title('Brasil')

axs[0,1].plot(df.loc['Colômbia', anos])
axs[0,1].set_title('Colômbia')

axs[1,0].plot(df.loc['Argentina', anos])
axs[1,0].set_title('Argentina')

axs[1,1].plot(df.loc['Peru', anos])
axs[1,1].set_title('Peru')

#ajustando o eixo de X (anos )
for ax in axs.flat:
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))

#incluindo rotulos
for ax in axs.flat:
    ax.set(xlabel='Ano', ylabel='Número de Imigrantes')
plt.show()

# %%
#criando 4 figuras
fig, axs = plt.subplots(2,2, figsize = (10,6))
fig.subplots_adjust(hspace = 0.5, wspace=0.3)
axs[0,0].plot(df.loc['Brasil', anos])
axs[0,0].set_title('Brasil')

axs[0,1].plot(df.loc['Colômbia', anos])
axs[0,1].set_title('Colômbia')

axs[1,0].plot(df.loc['Argentina', anos])
axs[1,0].set_title('Argentina')

axs[1,1].plot(df.loc['Peru', anos])
axs[1,1].set_title('Peru')

#ajustando o eixo de X (anos )
for ax in axs.flat:
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))

#incluindo rotulos
for ax in axs.flat:
    ax.set(xlabel='Ano', ylabel='Número de Imigrantes')

#ajustando os valores do eixo Y
ymin = 0
ymax = 7000

for ax in axs.ravel():
  ax.set_ylim(ymin, ymax)


plt.show()

# %%
#criando 4 figuras
fig, axs = plt.subplots(2,2, figsize = (10,6))
fig.subplots_adjust(hspace = 0.5, wspace=0.3)

#incluindo um titulo geral
fig.suptitle('Imigração dos quatro maiores países da América do Sul para o Canadá \n 1980 a 2013')

axs[0,0].plot(df.loc['Brasil', anos])
axs[0,0].set_title('Brasil')

axs[0,1].plot(df.loc['Colômbia', anos])
axs[0,1].set_title('Colômbia')

axs[1,0].plot(df.loc['Argentina', anos])
axs[1,0].set_title('Argentina')

axs[1,1].plot(df.loc['Peru', anos])
axs[1,1].set_title('Peru')

#ajustando o eixo de X (anos )
for ax in axs.flat:
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))

#incluindo rotulos
for ax in axs.flat:
    ax.set(xlabel='Ano', ylabel='Número de Imigrantes')

#ajustando os valores do eixo Y
ymin = 0
ymax = 7000

for ax in axs.ravel():
  ax.set_ylim(ymin, ymax)


plt.show()

# %% [markdown]
# * **Brasil** apresenta dois momentos de grande volume de imigração, de 1990-1994 e 2005-2010.
# * **Colômbia** apresenta um crescimento na imigração para o Canadá a partir de 2000, se acentuando em 2005. Possui um volume de imigração bem mais alto do que os demais países da América Latina
# * **Argentina** apresenta dois picos de imigração de 1990-1994 e 2002-2005, tendo um volume de imigração parecido com o do Brasil.
# * **Peru** Teve um grande volume de imigração de 1985-1995 e depois 2003-2010.

# %%
#Personalisando os gráficos
fig, ax = plt.subplots(figsize = (8,4))
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
#personalizando o titulo
ax.set_title('Imigração do Brasil para o Canadá\n(1980-2014)', fontsize=18)
ax.set_xlabel('Ano')
ax.set_ylabel('Número de Imigrantes')
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
plt.show()

# %%
#Personalisando os gráficos
fig, ax = plt.subplots(figsize = (8,4))
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
#personalizando o titulo
ax.set_title('Imigração do Brasil para o Canadá\n(1980-2014)', fontsize=18)
#personalizando os rotulos
ax.set_xlabel('Ano', fontsize = 14)
ax.set_ylabel('Número de Imigrantes', fontsize=14)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
plt.show()

# %%
#Personalisando os gráficos
fig, ax = plt.subplots(figsize = (8,4))
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
#personalizando o titulo
ax.set_title('Imigração do Brasil para o Canadá\n(1980-2014)', fontsize=18)
#personalizando os rotulos
ax.set_xlabel('Ano', fontsize = 14)
ax.set_ylabel('Número de Imigrantes', fontsize=14)
#personalizando os stikers
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
plt.show()

# %%
#Personalisando os gráficos
fig, ax = plt.subplots(figsize = (8,4))
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'])

#personalizando o titulo e colocando para a esquerda
ax.set_title('Imigração do Brasil para o Canadá\n(1980-2014)', fontsize=18, loc='left')

#personalizando os rotulos
ax.set_xlabel('Ano', fontsize = 14)
ax.set_ylabel('Número de Imigrantes', fontsize=14)

#personalizando os stikers
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
plt.show()

# %%
#Personalisando os gráficos e alterando a espessura da linha
fig, ax = plt.subplots(figsize = (8,4))
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3)

#personalizando o titulo e colocando para a esquerda
ax.set_title('Imigração do Brasil para o Canadá\n(1980-2014)', fontsize=18, loc='left')

#personalizando os rotulos
ax.set_xlabel('Ano', fontsize = 14)
ax.set_ylabel('Número de Imigrantes', fontsize=14)

#personalizando os stikers
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
plt.show()

# %%
#Personalisando os gráficos e alterando a espessura da linha e incluindo marcadores
fig, ax = plt.subplots(figsize = (8,4))
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3, marker='o')

#personalizando o titulo e colocando para a esquerda
ax.set_title('Imigração do Brasil para o Canadá\n(1980-2014)', fontsize=18, loc='left')

#personalizando os rotulos
ax.set_xlabel('Ano', fontsize = 14)
ax.set_ylabel('Número de Imigrantes', fontsize=14)

#personalizando os stikers
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
plt.show()

# %%
#Personalisando os gráficos e alterando a espessura da linha
fig, ax = plt.subplots(figsize = (8,4))
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3)

#personalizando o titulo e colocando para a esquerda
ax.set_title('Imigração do Brasil para o Canadá\n(1980-2014)', fontsize=18, loc='left')

#personalizando os rotulos
ax.set_xlabel('Ano', fontsize = 14)
ax.set_ylabel('Número de Imigrantes', fontsize=14)

#personalizando os stikers
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))

#incluindo a grade
plt.grid()
plt.show()

# %%
#Personalisando os gráficos e alterando a espessura da linha
fig, ax = plt.subplots(figsize = (8,4))
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3)

#personalizando o titulo e colocando para a esquerda
ax.set_title('Imigração do Brasil para o Canadá\n(1980-2014)', fontsize=18, loc='left')

#personalizando os rotulos
ax.set_xlabel('Ano', fontsize = 14)
ax.set_ylabel('Número de Imigrantes', fontsize=14)

#personalizando os stikers
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))

#incluindo a grade e personalizando ele
plt.grid(linestyle='--')
plt.show()

# %%
#personalizando as cores
fig, ax = plt.subplots(figsize = (8,4))
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3, color='m')
ax.set_title('Imigração do Brasil para o Canadá\n(1980-2014)', fontsize=18, loc='left')
ax.set_xlabel('Ano', fontsize = 14)
ax.set_ylabel('Número de Imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
plt.show()

# %%
#variavel com uma consulta
america_sul = df.query('Região == "América do Sul"')

# %%
america_sul
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
# Equador    América Latina e o Caribe  América do Sul   238   207   184   155
# Guiana     América Latina e o Caribe  América do Sul  2334  2943  3575  2650
# Paraguai   América Latina e o Caribe  América do Sul    45    26    32    40
# Peru       América Latina e o Caribe  América do Sul   317   456   401   241
# Suriname   América Latina e o Caribe  América do Sul    15    10    21    12
# Uruguai    América Latina e o Caribe  América do Sul   128   132   146   105
# ...

# %%
#variavel para as cores das barras
cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']
#gráfico de barras com os paises da região "América Latina"
fig, ax = plt.subplots(figsize = (12,5))
ax.bar(america_sul.index, america_sul['Total'], color=cores)
ax.set_title('Imigração da América do sul para o Canadá\n1980 a 2013' , loc= 'left', fontsize=18)
ax.set_xlabel('', fontsize=14)
ax.set_ylabel('Número de Imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
plt.show()

# %%
#gráfico de barras invertidas
cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

fig, ax = plt.subplots(figsize = (12,5))
#barras na horizontal
ax.barh(america_sul.index, america_sul['Total'], color=cores)
ax.set_title('Imigração da América do sul para o Canadá\n1980 a 2013' , loc= 'left', fontsize=18)
#trocando o rotulo dos eixos
ax.set_xlabel('Número de Imigrantes', fontsize=14)
ax.set_ylabel('', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
plt.show()

# %%
#ordenando as barras
america_sul_sorted = america_sul.sort_values('Total', ascending=True)

#ordenando o gráfico
cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

fig, ax = plt.subplots(figsize = (12,5))
#barras na horizontal
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
ax.set_title('Imigração da América do sul para o Canadá\n1980 a 2013' , loc= 'left', fontsize=18)
#trocando o rotulo dos eixos
ax.set_xlabel('Número de Imigrantes', fontsize=14)
ax.set_ylabel('', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
plt.show()

# %%
#destacando uma informação
cores = []

for pais in america_sul_sorted.index:
  if pais == 'Brasil':
    cores.append('green')
  else:
    cores.append('silver')

fig, ax = plt.subplots(figsize = (12,5))
#barras na horizontal
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
ax.set_title('América do sul: Brasil foi o quarto país com mais imigrantes\n para o Canadá no período de 1980 a 2013' , loc= 'left', fontsize=18)
#trocando o rotulo dos eixos
ax.set_xlabel('Número de Imigrantes', fontsize=14)
ax.set_ylabel('', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
plt.show()

# %%
#adicionando anotações
#destacando uma informação
cores = []

for pais in america_sul_sorted.index:
  if pais == 'Brasil':
    cores.append('green')
  else:
    cores.append('silver')

fig, ax = plt.subplots(figsize = (12,5))
#barras na horizontal
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
ax.set_title('América do sul: Brasil foi o quarto país com mais imigrantes\n para o Canadá no período de 1980 a 2013' , loc= 'left', fontsize=18)
#trocando o rotulo dos eixos
ax.set_xlabel('Número de Imigrantes', fontsize=14)
ax.set_ylabel('', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

#adicionando anotações nas barras
for i, v in enumerate(america_sul_sorted['Total']):
  ax.text(v + 20, i, str(v), color='black', fontsize=10, ha='left', va= 'center')

plt.show()

# %%
#adicionando anotações
#destacando uma informação
cores = []

for pais in america_sul_sorted.index:
  if pais == 'Brasil':
    cores.append('green')
  else:
    cores.append('silver')

fig, ax = plt.subplots(figsize = (12,5))
#barras na horizontal
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
ax.set_title('América do sul: Brasil foi o quarto país com mais imigrantes\n para o Canadá no período de 1980 a 2013' , loc= 'left', fontsize=18)
#trocando o rotulo dos eixos
ax.set_xlabel('Número de Imigrantes', fontsize=14)
ax.set_ylabel('', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

#adicionando anotações nas barras
for i, v in enumerate(america_sul_sorted['Total']):
  ax.text(v + 20, i, str(v), color='black', fontsize=10, ha='left', va= 'center')

#retirando a borda do gráfico
ax.set_frame_on(False)
plt.show()

# %%
#Personalizando o gráfico
#destacando uma informação
cores = []

for pais in america_sul_sorted.index:
  if pais == 'Brasil':
    cores.append('green')
  else:
    cores.append('silver')

fig, ax = plt.subplots(figsize = (12,5))
#barras na horizontal
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
ax.set_title('América do sul: Brasil foi o quarto país com mais imigrantes\n para o Canadá no período de 1980 a 2013' , loc= 'left', fontsize=18)
#trocando o rotulo dos eixos
ax.set_xlabel('Número de Imigrantes', fontsize=14)
ax.set_ylabel('', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

#adicionando anotações nas barras
for i, v in enumerate(america_sul_sorted['Total']):
  ax.text(v + 20, i, str(v), color='black', fontsize=10, ha='left', va= 'center')

#retirando a borda do gráfico
ax.set_frame_on(False)

#retirando o eixo X
ax.get_xaxis().set_visible(False)
plt.show()

# %%
#Personalizando o gráfico
#destacando uma informação
cores = []

for pais in america_sul_sorted.index:
  if pais == 'Brasil':
    cores.append('green')
  else:
    cores.append('silver')

fig, ax = plt.subplots(figsize = (12,5))
#barras na horizontal
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
ax.set_title('América do sul: Brasil foi o quarto país com mais imigrantes\n para o Canadá no período de 1980 a 2013' , loc= 'left', fontsize=18)
#trocando o rotulo dos eixos
ax.set_xlabel('Número de Imigrantes', fontsize=14)
ax.set_ylabel('', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

#adicionando anotações nas barras
for i, v in enumerate(america_sul_sorted['Total']):
  ax.text(v + 20, i, str(v), color='black', fontsize=10, ha='left', va= 'center')

#retirando a borda do gráfico
ax.set_frame_on(False)

#retirando o eixo X
ax.get_xaxis().set_visible(False)

#retirando os tick entre o nome do pais e a barra
ax.tick_params(axis='both', which='both', length=0)
plt.show()

# %%
#Verificando os formatos possiveis para salvar o gráfico
print(fig.canvas.get_supported_filetypes())
# Out:
# {'eps': 'Encapsulated Postscript', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'ps': 'Postscript', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format', 'webp': 'WebP Image Format'}

# %%
#salvando gráfico em png

fig, ax = plt.subplots(figsize = (8,4))
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3)
ax.set_title('Imigração do Brasil para o Canadá\n(1980-2014)', fontsize=18, loc='left')
ax.set_xlabel('Ano', fontsize = 14)
ax.set_ylabel('Número de Imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig('imigracao_brasil_canada.png', transparent=False, dpi=300, bbox_inches='tight')

plt.show()

# %%
#salvando o grafico em png

cores = []

for pais in america_sul_sorted.index:
  if pais == 'Brasil':
    cores.append('green')
  else:
    cores.append('silver')

fig, ax = plt.subplots(figsize = (12,5))
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
ax.set_title('América do sul: Brasil foi o quarto país com mais imigrantes\n para o Canadá no período de 1980 a 2013' , loc= 'left', fontsize=18)
ax.set_xlabel('Número de Imigrantes', fontsize=14)
ax.set_ylabel('', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

for i, v in enumerate(america_sul_sorted['Total']):
  ax.text(v + 20, i, str(v), color='black', fontsize=10, ha='left', va= 'center')

ax.set_frame_on(False)
ax.get_xaxis().set_visible(False)
ax.tick_params(axis='both', which='both', length=0)
fig.savefig('imigracao_america_sul.png', transparent=False, dpi=300, bbox_inches='tight')
plt.show()

# %%
#Usando a biblioteca seaborn
import seaborn as sns

# %%
#definindo o tema do gráfico
sns.set_theme()

# %%
#criando o gráfico top 10

top_10 = df.sort_values('Total', ascending=False).head(10)

# %%
top_10
# Out:
#                                       Continente            Região   1980  \
# País
# Índia                                       Ásia       Sul da Ásia   8880
# China                                       Ásia     Ásia Oriental   5123
# Reino Unido e Irlanda do Norte            Europa   Norte da Europa  22045
# Filipinas                                   Ásia  Sudeste Asiático   6051
# Paquistão                                   Ásia       Sul da Ásia    978
# Estados Unidos da América       América do Norte  América do Norte   9378
# Irã                                         Ásia       Sul da Ásia   1172
# Sri Lanka                                   Ásia       Sul da Ásia    185
# República da Coreia                         Ásia     Ásia Oriental   1011
# Polônia                                   Europa   Europa Oriental    863
#
#                                  1981   1982   1983   1984  1985  1986   1987  \
# País
# ...

# %%
sns.barplot(data=top_10, x=top_10.index, y='Total')
# Out:
# <Axes: xlabel='País', ylabel='Total'>

# %%
sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h')
# Out:
# <Axes: xlabel='Total', ylabel='País'>

# %%
#personalizando o gráfico seaborn
ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h')
ax.set(title='Países com maior imigração para o Canadá\n 1980 a 2013',
       xlabel='Número de imigrantes',
       ylabel='')
plt.show()

# %%
#criando uma figura
fig, ax = plt.subplots(figsize = (8,4))
ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h')

ax.set_title('Países com maior imigração para o Canadá\n 1980 a 2013', loc='left', fontsize=16)
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
plt.show()

# %%
#usando diferentes tipos de paletas
fig, ax = plt.subplots(figsize = (8,4))
ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h')

ax.set_title('Países com maior imigração para o Canadá\n 1980 a 2013', loc='left', fontsize=16)
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
plt.show()

# %%
#função para gerar paletas
def gerar_grafico_paleta(palette):
  fig, ax = plt.subplots(figsize = (8,4))
  ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', hue='Total', palette=palette, legend=False)
  ax.set_title('Países com maior imigração para o Canadá\n 1980 a 2013', loc='left', fontsize=16)
  ax.set_xlabel('Número de imigrantes', fontsize=14)
  ax.set_ylabel('')
  plt.show()

#gerando gráficos
gerar_grafico_paleta('Blues')

# %%
#gerando gráficos
gerar_grafico_paleta('Blues')

# %%
#gerando gráficos
gerar_grafico_paleta('rocket')

# %%
gerar_grafico_paleta('coolwarm')

# %%
gerar_grafico_paleta('magma')

# %%
gerar_grafico_paleta('tab10')

# %%
#explorando temos
sns.set_theme(style='dark')
gerar_grafico_paleta('tab10')

# %%
sns.set_theme(style='whitegrid')
gerar_grafico_paleta('tab10')

# %%
sns.set_theme(style='white')
gerar_grafico_paleta('tab10')

# %%
sns.set_theme(style='ticks')
gerar_grafico_paleta('tab10')

# %%
#criando a figura sem a caixa
fig, ax = plt.subplots(figsize = (8,4))
ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', hue='Total', palette='tab10', legend=False)

ax.set_title('Países com maior imigração para o Canadá\n 1980 a 2013', loc='left', fontsize=18)
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
sns.despine()
plt.show()

# %%
#importanto a biblioteca ploty
import plotly.express as px

# %%
fig = px.line(dados_brasil, x='ano', y='imigrantes')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#alterando a altura e largura do gráfico
fig = px.line(dados_brasil, x='ano', y='imigrantes')
fig.update_layout(height=400, width=600,
                  xaxis={'tickangle':-45}) #rotacionando o rotulo do eixo x
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#alterando a altura e largura do gráfico
fig = px.line(dados_brasil, x='ano', y='imigrantes',
              title='Imigração do Brasil para o Canadá no período de 1980 a 2014')#incluindo titulo
fig.update_layout(height=500, width=1000,
                  xaxis={'tickangle':-45}) #rotacionando o rotulo do eixo x
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#alterando a altura e largura do gráfico
fig = px.line(dados_brasil, x='ano', y='imigrantes',
              title='Imigração do Brasil para o Canadá no período de 1980 a 2014') #incluindo titulo
fig.update_layout(height=500, width=1000,
                  xaxis={'tickangle':-45},#rotacionando o rotulo do eixo x
                  xaxis_title='Ano', #incluindo rotulos
                  yaxis_title='Número de imigrantes')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#alterando a altura e largura do gráfico
fig = px.line(dados_brasil, x='ano', y='imigrantes',
              title='Imigração do Brasil para o Canadá no período de 1980 a 2014') #incluindo titulo
fig.update_layout(height=500, width=1000,
                  xaxis={'tickangle':-45},#rotacionando o rotulo do eixo x
                  font_family='Arial', #personalizando letra
                  font_size=14,
                  font_color='gray',
                  title_font_color='black',#personalizando o titulo
                  title_font_size=22,
                  xaxis_title='Ano', #incluindo rotulos
                  yaxis_title='Número de imigrantes')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#alterando a altura e largura do gráfico
fig = px.line(dados_brasil, x='ano', y='imigrantes',
              title='Imigração do Brasil para o Canadá no período de 1980 a 2014') #incluindo titulo
fig.update_traces(line_color='green', line_width=4) #alterando a cor da linha
fig.update_layout(height=500, width=1000,
                  xaxis={'tickangle':-45},#rotacionando o rotulo do eixo x
                  font_family='Arial', #personalizando letra
                  font_size=14,
                  font_color='gray',
                  title_font_color='black',#personalizando o titulo
                  title_font_size=22,
                  xaxis_title='Ano', #incluindo rotulos
                  yaxis_title='Número de imigrantes')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
america_sul.head()
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
#
#            1984  1985  1986  1987  ...  2005  2006  2007  2008  2009  2010  \
# País                               ...
# Argentina   237   196   213   519  ...  1153   847   620   540   467   459
# Bolívia      38    44    79   165  ...   134   139   107   143   214   180
# Brasil      145   130   205   244  ...   969  1181  1746  2138  2509  2598
# Chile       681   533   633  1454  ...   384   427   530   350   375   340
# Colômbia    235   214   257   376  ...  6424  6535  5357  5452  4652  5218
#
# ...

# %%
df_america_sul_clean = america_sul.drop(['Continente','Região','Total'], axis=1)
america_sul_final = df_america_sul_clean.T
america_sul_final.head()
# Out:
# País  Argentina  Bolívia  Brasil  Chile  Colômbia  Equador  Guiana  Paraguai  \
# 1980        368       44     211   1233       266      238    2334        45
# 1981        426       52     220   1069       326      207    2943        26
# 1982        626       42     192   1078       360      184    3575        32
# 1983        241       49     139    781       244      155    2650        40
# 1984        237       38     145    681       235      179    1932        48
#
# País  Peru  Suriname  Uruguai  Venezuela
# 1980   317        15      128        103
# 1981   456        10      132        117
# 1982   401        21      146        174
# 1983   241        12      105        124
# 1984   306         5       90        142

# %%
#criando o gráfico
fig = px.line(america_sul_final, x=america_sul_final.index, y=america_sul_final.columns,
              color='País', title='Imigração dos países da América do Sul para o Canadá\n1980 a 2013')

fig.update_layout(
    xaxis = {'tickangle':-45},
    xaxis_title='Ano',
    yaxis_title='Número de imigrantes'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#criando o gráfico com marcadores
fig = px.line(america_sul_final, x=america_sul_final.index, y=america_sul_final.columns,
              color='País', title='Imigração dos países da América do Sul para o Canadá\n1980 a 2013',
              markers=True)

fig.update_layout(
    xaxis = {'tickangle':-45},
    xaxis_title='Ano',
    yaxis_title='Número de imigrantes'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html('imigracao_america_sul.html')

# %% [markdown]
# ##**Grafico animado com os dados somente do Brasil**

# %%
import plotly.graph_objs as go

# Criando uma figura
fig = go.Figure()

# Adicionando a linha do gráfico e definindo a espessura da linha
fig.add_trace(
    go.Scatter(x=[dados_brasil['ano'].iloc[0]], y=[dados_brasil['imigrantes'].iloc[0]], mode='lines', name='Imigrantes', line=dict(width=4))
)

# Definindo as configurações de layout
fig.update_layout(
    title=dict(
        text='<b>Imigração do Brasil para o Canadá no período de 1980 a 2013</b>',
        x=0.12,
        xanchor='left',
        font=dict(size=20)
    ),
    xaxis=dict(range=[1980, 2013], autorange=False, title='<b>Ano</b>'),
    yaxis=dict(range=[0, 3000], autorange=False, title='<b>Número de imigrantes</b>'),
    updatemenus=[dict(
        type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}]
        )]
    )],
    width=1000,
    height=500
)

# Definir as configurações de animação
frames = [go.Frame(data=[go.Scatter(x=dados_brasil['ano'].iloc[:i+1], y=dados_brasil['imigrantes'].iloc[:i+1])]) for i in range(len(dados_brasil))]
fig.frames = frames

# Mostrando a figura
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##**Desafio: Criando uma animação para comparar diferentes dados**

# %%
import plotly.graph_objs as go
#Dados Brasil e Dados Argentina


# Criando uma figura
fig = go.Figure()

# Adicionando a linha com os dados do Brasil
fig.add_trace(
    go.Scatter(x=[dados_brasil['ano'].iloc[0]], y=[dados_brasil['imigrantes'].iloc[0]], mode='lines', name='Imigrantes do Brasil', line=dict(width=4))
)

# Adicionando a linha com os dados da Argentina
fig.add_trace(
    go.Scatter(x=[dados_argentina['ano'].iloc[0]], y=[dados_argentina['imigrantes'].iloc[0]], mode='lines', name='Imigrantes da Argentina', line=dict(width=4))
)

# Definindo as configurações de layout
fig.update_layout(
    title=dict(
        text='<b>Imigração do Brasil e da Argentina para o Canadá no período de 1980 a 2013',
        x=0.1,

        font=dict(size=18)
    ),
    xaxis=dict(range=[1980, 2013], autorange=False, title='<b>Ano</b>'),
    yaxis=dict(range=[0, 3000], autorange=False, title='<b>Número de imigrantes</b>'),
    updatemenus=[dict(
        type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}]
        )]
    )],
    width=1200, # largura da figura em pixels
    height=600 # altura da figura em pixels
)

# Definindo as configurações de animação
frames = []
for i in range(len(dados_brasil)):
    frame_data = [
        go.Scatter(x=dados_brasil['ano'].iloc[:i+1], y=dados_brasil['imigrantes'].iloc[:i+1]),
        go.Scatter(x=dados_argentina['ano'].iloc[:i+1], y=dados_argentina['imigrantes'].iloc[:i+1])
    ]
    frame = go.Frame(data=frame_data)
    frames.append(frame)
fig.frames = frames

# Mostrando a figura
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html('comparacao_brasil_argentina.html')

# %% [markdown]
# ##**Desafio: criando um gráfico de linhas com a biblioteca seaborn**

# %%
#Definir o tema
sns.set_theme()
#definir a paleta
sns.set_palette('Dark2')

#criar uma figura com tamanho definido
fig, ax = plt.subplots(figsize=(10, 5))
#plotar as linhas para cada país com a label(país) e tamanho(3pixels)
ax = sns.lineplot(df.loc['Brasil', anos], label='Brasil', lw=3)
ax = sns.lineplot(df.loc['Argentina', anos], label='Argentina', lw=3)
ax = sns.lineplot(df.loc['Peru', anos], label='Peru', lw=3)
ax = sns.lineplot(df.loc['Colômbia', anos], label='Colômbia', lw=3)

#Define o titulo e rotulos
ax.set_title('Imigração dos maiores países da América do Sul\npara o Canadá de 1980 a 2013', loc='left', fontsize=20)
ax.set_xlabel('Ano', fontsize=14)
ax.set_ylabel('Número de imigrantes', fontsize=14)

ax.xaxis.set_major_locator(plt.MultipleLocator(5))
#definir legenda do gráfico
ax.legend(title='Países', loc='upper right', bbox_to_anchor=(1.18, 1.02))
#exibir o gráfico
plt.show()
